# %% [markdown]
# # OpenCVインストール確認

# %%
# OpenCVのライブラリをインポート
import cv2

# OpenCVのバージョン情報を表示する
print(f"cv2 ver : {cv2.__version__}")
# Out:
# cv2 ver : 4.10.0

# %% [markdown]
# # 2. OpenCVで画像の操作

# %% [markdown]
# ## 2-1. 画像の読み込み

# %%
# OpenCVをインポート
import cv2

# 画像ファイルを読み込む
img = cv2.imread("man.jpg")

# 読み込んだ画像のデータを出力する
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# OpenCVをインポート
import cv2

# 読み込み失敗の確認用
img = cv2.imread('存在しない画像.png')

# 読み込んだ画像のデータを出力する
print(img)
# Out:
# None

# %% [markdown]
# ## 2-2. 画像の表示

# %%
# matplotlibとOpenCVをインポート
import matplotlib.pyplot as plt
import cv2

# 画像ファイルを読み込む
img = cv2.imread("man.jpg")

# BGRからRGBに変換して、画像を表示する
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# 画像を表示する
plt.show()

# %%
# matplotlibとOpenCVをインポート
import matplotlib.pyplot as plt
import cv2

# 画像ファイルを読み込む
img = cv2.imread("man.jpg")

# 軸を非表示にして、画像を表示する
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# 画像を表示する
plt.show()

# %% [markdown]
# ## 2-3. 画像のリサイズと切り取り
# ### 2-3-1. 画像のリサイズ

# %%
# matplotlibとOpenCVをインポート
import matplotlib.pyplot as plt
import cv2

# 画像ファイルを読み込む
img = cv2.imread("man.jpg")

# 画像のサイズを変更し、変更した画像をファイルに保存する
img2 = cv2.resize(img, (600, 300))
cv2.imwrite("out-resize.png", img2)

# 変更した画像を表示する
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### 2-3-2. 画像の切り取り

# %%
# OpenCVとMatplotlibをインポート
import cv2
import matplotlib.pyplot as plt

# 画像ファイルを読み込む
img = cv2.imread("man.jpg")

# 画像の一部を切り出し、サイズを変更し、ファイルに保存する
img2 = img[200:500, 900:1200]
img2 = cv2.resize(img2, (400, 400))

# 変更した画像を表示する
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### 2-3-3. 輪郭検出

# %%
# 画像ファイルを読み込む
img = cv2.imread("man.jpg")
# imgがcv2カラーの場合、グレースケールに変換しておく
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Cannyエッジ検出を適用
edges = cv2.Canny(img, 100, 200)
# 表示してみる
plt.imshow(edges)
plt.show()

# %% [markdown]
# ## 2-4. 画像の保存

# %%
# 画像の保存
cv2.imwrite("cut_resize.png", img2)
# Out:
# True

# %% [markdown]
# # 3. 動画の操作

# %% [markdown]
# ## 3-2. 動画の読み込み

# %%
# OpenCVをインポート
import cv2

# 動画ファイルを読み込む
cap = cv2.VideoCapture("bird.mp4")

# %%
# 1フレームを読み込む
res, frame = cap.read()
# 表示して確認
print(res)
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# True

# %% [markdown]
# <h2> 3-4. 動画ファイルの保存</h2>

# %% [markdown]
# <h3>3-4-1. 書き込む動画ファイルのコーデックを指定 : cv2.VideoWriter_fourcc( )</h3>

# %%
# mp4vを指定する場合
fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
# fourcc = cv2.VideoWriter_fourcc(*'mp4v') # と書いてもいい

# %% [markdown]
# <h3>3-4-2. 書き込み用のオブジェクトを生成 : cv2.VideoWriter( )</h3>

# %%
# パラメータを指定
width = 600
height = 400
fps = 30 

# 出力用のVideoWriterオブジェクトを作成
out = cv2.VideoWriter('output_video.mp4', fourcc, fps, (width, height))

# %% [markdown]
# <h3>3-4-3. 動画ファイルに書き込む cv2.VideoWriter.write( )</h3>

# %%
# ここはループ内
# 処理したフレームを書き込む
out.write(frame)

# %% [markdown]
# ## 3-5. 動画ファイルを閉じる

# %%
# VideoCaptureオブジェクトを解放
cap.release()
out.release()

# %% [markdown]
# **※動画を表示しながら確認する場合は、VS Codeで.pyを開いて実行するようにしましょう。**

# %% [markdown]
# ## 3-6. 繰り返し処理による動画ファイルの処理と保存

# %%
# 動画処理の例
import cv2

# 入力動画ファイルを開く
cap = cv2.VideoCapture('input_video.mp4')

# 動画ファイルの情報を取得
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# 出力用のVideoWriterオブジェクトを作成
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_video.mp4', fourcc, fps, (width, height), isColor=False)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # フレームをグレースケールに変換
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # グレースケールフレームを書き込む
    out.write(gray)
    
    # フレームを表示（オプション）-> Jupyterでは表示しない方がよい
    # cv2.imshow('Frame', gray)
    
    # 'q'キーが押されたら終了
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# リソースを解放
cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 4. カメラを使用した画像/動画の取得

# %% [markdown]
# ## 4-1. カメラからの画像取得

# %%
# カメラからの画像取得
import cv2

# カメラを開く
cap = cv2.VideoCapture(0)

# フレームを取得
ret, frame = cap.read()

# 画像を表示
cv2.imshow('Camera', frame)
cv2.waitKey(0)

# カメラを解放
cap.release()
cv2.destroyAllWindows()
